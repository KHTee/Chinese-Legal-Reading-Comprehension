# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Install packages

# %%
# !pip install 'torch==1.0.0' 'spacy==2.0.16' 'torchtext==0.4.0' 'torchvision==0.2.1'   'tensorflow==2.3.0' 'numpy==1.18.5'
# Out:
# ...
#      |████████████████████████████████| 143kB 30.3MB/s
# ...
#   Created wheel for msgpack: filename=msgpack-0.5.6-cp37-cp37m-linux_x86_64.whl size=298841 sha256=3cf0b64a38f69fa7b374d110b3aed8816b7f4e33ea0ce8514ef42f6dc0d987e1
#   Stored in directory: /root/.cache/pip/wheels/f0/02/4c/525b56fce78c415eb8066f6554f9de02792df26b8f882f6d65
# Successfully built msgpack
# ERROR: thinc 6.12.1 has requirement wrapt<1.11.0,>=1.10.0, but you'll have wrapt 1.12.1 which is incompatible.
# ERROR: fastai 1.0.61 has requirement spacy>=2.0.18; python_version < "3.8", but you'll have spacy 2.0.16 which is incompatible.
# ERROR: en-core-web-sm 2.2.5 has requirement spacy>=2.2.2, but you'll have spacy 2.0.16 which is incompatible.
# ...
#   Found existing installation: msgpack 1.0.2
#     Uninstalling msgpack-1.0.2:
#       Successfully uninstalled msgpack-1.0.2
# ...

# %%
# !pip install ujson tqdm urllib3

# %%
# !pip install transformers pytorch-transformers tensorboard tensorboardx

# %%
# !pip install jieba

# %%
# !pip install overrides

# %% [markdown]
# # Run

# %%
# %cd ~/bidaf_v3
# Out:
# ~/bidaf_v3

# %%
# !python main.py # 8 min
# Out:
# Streaming output truncated to the last 5000 lines.
#          2.1129e-03],
#         [1.7041e-03, 2.5023e-05, 3.7378e-06,  ..., 3.5211e-03, 2.2847e-02,
#          9.2500e-05],
#         [8.8597e-03, 2.4352e-04, 5.3206e-05,  ..., 3.3290e-04, 8.9447e-04,
#          3.5895e-05],
#         ...,
#         [3.5026e-02, 2.5636e-03, 7.4128e-03,  ..., 1.1413e-04, 9.3047e-04,
#          6.3930e-04],
#         [2.2215e-02, 8.7670e-04, 8.5447e-04,  ..., 9.4301e-04, 6.3176e-03,
#          9.3018e-03],
#         [9.4825e-03, 3.6523e-04, 3.2349e-04,  ..., 1.1836e-03, 1.9160e-03,
#          1.2836e-03]], device='cuda:0')
# dataloader p2: tensor([[6.7736e-02, 1.3265e-03, 4.0558e-03,  ..., 2.3582e-03, 4.5431e-03,
#          1.0612e-04],
#         [4.7668e-03, 1.3234e-05, 5.4392e-06,  ..., 5.0193e-07, 7.1346e-05,
#          3.7363e-03],
#         [1.0767e-02, 1.0891e-04, 6.7561e-05,  ..., 1.3434e-06, 2.4681e-05,
#          2.4509e-04],
#         ...,
# ...

# %%
# !python evaluate.py --data-file data/test-v2.0.json --pred-file save/test/test-01/result.json
# Out:
# OrderedDict([('civil', {'em': 41.5, 'f1': 55.2, 'qas': 3000}), ('criminal', {'em': 29.7, 'f1': 45.9, 'qas': 3000}), ('overall', {'em': 35.6, 'f1': 50.5, 'qas': 6000})])
